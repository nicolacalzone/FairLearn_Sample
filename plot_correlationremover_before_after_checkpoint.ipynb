# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolacalzone/FairLearn_Sample/blob/main/plot_correlationremover_before_after_checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CorrelationRemover visualization
# ================================

# %% [markdown]
# This notebook demonstrates the use of the `fairlearn.preprocessing.CorrelationRemover` class. We will show this by looking at the correlation
# matrices of the dataset before and after the CorrelationRemover.
#
# Getting the Data
# ================

# %%
pip install fairlearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from fairlearn.datasets import fetch_diabetes_hospital
from fairlearn.preprocessing import CorrelationRemover

# %% [markdown]
# We drop most dummy columns that are created, since we are
# looking specifically at the African American race. Finally, the columns
# are rearranged for consistency.

# %%
data = fetch_diabetes_hospital()
X_raw_initial = data.data[["race", "time_in_hospital", "had_inpatient_days", "medicare"]]
X_raw = pd.get_dummies(X_raw_initial)
X_raw1 = pd.get_dummies(X_raw)
y = data.target

X_raw = X_raw.drop(
    [
        "race_Asian",
        "race_Caucasian",
        "race_Hispanic",
        "race_Other",
        "race_Unknown",
        "had_inpatient_days_False",
        "medicare_False",
    ],
    axis=1,
)

X_raw = X_raw[
    [
        "time_in_hospital",
        "had_inpatient_days_True",
        "medicare_True",
        "race_AfricanAmerican",
    ]
]

X_raw1 = X_raw1[
    [
        "time_in_hospital",
        "had_inpatient_days_True",
        "medicare_True",
        "race_Caucasian",
    ]
]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/_openml.py:968: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(

# %%
data.data.head()
# Out:
#               race  gender                  age discharge_disposition_id  \
# 0        Caucasian  Female  30 years or younger                    Other
# 1        Caucasian  Female  30 years or younger       Discharged to Home
# 2  AfricanAmerican  Female  30 years or younger       Discharged to Home
# 3        Caucasian    Male          30-60 years       Discharged to Home
# 4        Caucasian    Male          30-60 years       Discharged to Home
#
#   admission_source_id  time_in_hospital medical_specialty  num_lab_procedures  \
# 0            Referral                 1             Other                  41
# 1           Emergency                 3           Missing                  59
# 2           Emergency                 2           Missing                  11
# 3           Emergency                 2           Missing                  44
# 4           Emergency                 1           Missing                  51
#
# ...

# %%
X_raw_initial = data.data[["gender", "time_in_hospital", "had_inpatient_days", "medicare"]]
X_raw_gender = pd.get_dummies(X_raw_initial)

# %% [markdown]
# We are now going to fit the CorrelationRemover to the data, and
# transform it. The transformed array will be placed back in a Pandas
# DataFrame, for plotting purposes.
#
# Removal of Correlations for 'race'
# ================

# %%
###############

## African American people


#############
# ALPHA = 0 # --> NO CorrelationRemover applied. Data is raw.
#############
cr = CorrelationRemover(sensitive_feature_ids=["race_AfricanAmerican"], alpha=0)
X_cr = cr.fit_transform(X_raw)
X_cr = pd.DataFrame(
    X_cr, columns=["time_in_hospital", "had_inpatient_days_True", "medicare_True"]
)
X_cr["race_AfricanAmerican"] = X_raw["race_AfricanAmerican"]


#############
# ALPHA = 1 # --> --> CorrelationRemover is applied. Data is processed.
#############
cr_alpha = CorrelationRemover(sensitive_feature_ids=["race_AfricanAmerican"], alpha=1)
X_cr_alpha = cr_alpha.fit_transform(X_raw)
X_cr_alpha = pd.DataFrame(
    X_cr_alpha, columns=["time_in_hospital", "had_inpatient_days_True", "medicare_True"]
)
X_cr_alpha["race_AfricanAmerican"] = X_raw["race_AfricanAmerican"]

###############

## Caucasian people

#############
# ALPHA = 0 # --> NO CorrelationRemover applied. Data is raw.
#############
cr1 = CorrelationRemover(sensitive_feature_ids=["race_Caucasian"], alpha=0)
X_cr1 = cr1.fit_transform(X_raw1)
X_cr1 = pd.DataFrame(
    X_cr1, columns=["time_in_hospital", "had_inpatient_days_True", "medicare_True"]
)
X_cr1["race_Caucasian"] = X_raw1["race_Caucasian"]


#############
# ALPHA = 1 # --> --> CorrelationRemover is applied. Data is processed.
#############
cr0 = CorrelationRemover(sensitive_feature_ids=["race_Caucasian"], alpha=1)
X_cr0 = cr0.fit_transform(X_raw1)
X_cr0 = pd.DataFrame(
    X_cr0, columns=["time_in_hospital", "had_inpatient_days_True", "medicare_True"]
)
X_cr0["race_Caucasian"] = X_raw1["race_Caucasian"]

# %% [markdown]
# We can now plot the correlation matrices before and after the
# CorrelationRemover. The code is from the [matplotlib
# docs](https://matplotlib.org/devdocs/gallery/images_contours_and_fields/image_annotated_heatmap.html).

# %%
def plot_heatmap(df, title):
    df["target"] = y
    df = df.rename(columns={"had_inpatient_days_True": "had_inpatient_days"})
    cols = list(df.columns)

    fig, ax = plt.subplots(figsize=(8, 6))
    ax.imshow(round(df.corr(), 2), cmap="coolwarm")

    # Show all ticks and label them with the respective list entries
    ax.set_xticks(np.arange(len(cols)), labels=cols)
    ax.set_yticks(np.arange(len(cols)), labels=cols)

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=15, ha="right", rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    for i in range(len(cols)):
        for j in range(len(cols)):
            ax.text(
                j,
                i,
                round(df.corr().to_numpy()[i, j], 2),
                ha="center",
                va="center",
            )

    ax.set_title(f"{title}")
    plt.show()

# %% [markdown]
# Heatmaps for 'race'
# ================
#
# Correlation values for AfricanAmerican and Caucasian people
#
# *   1st Heatmap has original values
# *   2nd Heatmap has values after removal of sensitive correlations

# %% [markdown]
# **For African Americans:**

# %%
plot_heatmap(X_cr, "Correlation values in original dataset for African American people ")
plot_heatmap(X_cr_alpha, "Correlation values after CorrelationRemover for African American people ")

# %% [markdown]
# **For Caucasians:**

# %%
plot_heatmap(X_cr1, "Correlation values in original dataset for Caucasian people")
plot_heatmap(X_cr0, "Correlation values after CorrelationRemover for Caucasian people")

# %% [markdown]
# Removal of Correlations for 'gender'
# ================

# %%
###############

## Males

X_raw_male = X_raw_gender.drop(
    [
        "had_inpatient_days_False",
        "medicare_False",
        "gender_Female",
        "gender_Unknown/Invalid"
    ],
    axis=1,
)

X_raw_gender_male = X_raw_gender[
    [
        "time_in_hospital",
        "had_inpatient_days_True",
        "medicare_True",
        "gender_Male",  ##
    ]
]

###############

## Females

X_raw_female = X_raw_gender.drop(
    [
        "had_inpatient_days_False",
        "medicare_False",
        "gender_Male",
        "gender_Unknown/Invalid",
    ],
    axis=1,
)

X_raw_gender_female = X_raw_gender[
    [
        "time_in_hospital",
        "had_inpatient_days_True",
        "medicare_True",
        "gender_Female", ##
    ]
]

# %% [markdown]
# > Here CorrelationRemover is applied for another `sensitive_feature`: gender.

# %%
#############
# ALPHA = 0 # --> NO CorrelationRemover applied. Data is raw.
############

cr_male = CorrelationRemover(sensitive_feature_ids=["gender_Male"], alpha=0)
X_cr_male = cr_male.fit_transform(X_raw_gender_male)
X_cr_male = pd.DataFrame(
    X_cr_male, columns=["time_in_hospital", "had_inpatient_days_True", "medicare_True"]
)
X_cr_male["gender_Male"] = X_raw_gender_male["gender_Male"]
#X_cr_male["race_gender"] = X_cr_male.apply(lambda row: f'{row["race_Caucasian"]}_{row["gender_Male"]}', axis=1)


cr_female = CorrelationRemover(sensitive_feature_ids=["gender_Female"], alpha=0)
X_cr_female = cr_female.fit_transform(X_raw_gender_female)
X_cr_female = pd.DataFrame(
    X_cr_female, columns=["time_in_hospital", "had_inpatient_days_True", "medicare_True"]
)
X_cr_female["gender_Female"] = X_raw_gender_female["gender_Female"]
#X_cr_female["race_gender"] = X_cr_female.apply(lambda row: f'{row["race_AfricanAmerican"]}_{row["gender_Female"]}', axis=1)

#############
# ALPHA = 1 # --> --> CorrelationRemover is applied. Data is processed.
#############
cr1_male = CorrelationRemover(sensitive_feature_ids=["gender_Male"], alpha=1)
X_cr1_male = cr1_male.fit_transform(X_raw_gender_male)
X_cr1_male = pd.DataFrame(
    X_cr1_male, columns=["time_in_hospital", "had_inpatient_days_True", "medicare_True"]
)
X_cr1_male["gender_Male"] = X_raw_gender_male["gender_Male"]

cr1_female = CorrelationRemover(sensitive_feature_ids=["gender_Female"], alpha=1)
X_cr1_female = cr1_female.fit_transform(X_raw_gender_female)
X_cr1_female = pd.DataFrame(
    X_cr1_female, columns=["time_in_hospital", "had_inpatient_days_True", "medicare_True"]
)
X_cr1_female["gender_Female"] = X_raw_gender_female["gender_Female"]

# %% [markdown]
# Heatmaps for 'gender'
# ================
#
# Correlation values for Males and Females. As before:
#
# *   1st Heatmap has original values
# *   2nd Heatmap has values after removal of sensitive correlations

# %%
plot_heatmap(X_cr_male, "Correlation values in original dataset for Males")
plot_heatmap(X_cr_female, "Correlation values in original dataset for Females")

# %%
plot_heatmap(X_cr1_male, "Correlation values after CorrelationRemover for Males")
plot_heatmap(X_cr1_female, "Correlation values after CorrelationRemover for Females")
